# %% [markdown]
# # ECE 884 Deep Learning - Final Project
# *Notebook 2 of 3 - Sheet 2*<br>
# **Name:** Syed Kashif Mujtaba Kamoonpuri<br>
# **Email:** kamoonpu@msu.edu
#
# **Objective:**<br>
# Pre-process data. This includes:
# - Dealing with missing values
# - Scaling numerical variables

# %% [markdown]
# **Importing required libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Loading dataset**

# %%
train = pd.read_csv('train.csv', parse_dates=['Date'])
test = pd.read_csv('test.csv', parse_dates=['Date'])
print('Dimensions of training set:', train.shape)
print('Dimensions of testing set:', test.shape)
# Out:
# Dimensions of training set: (35995, 6)
# Dimensions of testing set: (13459, 4)

# %%
train.head(10)
# Out:
#    Id Province_State Country_Region       Date  ConfirmedCases  Fatalities
# 0   1            NaN    Afghanistan 2020-01-22             0.0         0.0
# 1   2            NaN    Afghanistan 2020-01-23             0.0         0.0
# 2   3            NaN    Afghanistan 2020-01-24             0.0         0.0
# 3   4            NaN    Afghanistan 2020-01-25             0.0         0.0
# 4   5            NaN    Afghanistan 2020-01-26             0.0         0.0
# 5   6            NaN    Afghanistan 2020-01-27             0.0         0.0
# 6   7            NaN    Afghanistan 2020-01-28             0.0         0.0
# 7   8            NaN    Afghanistan 2020-01-29             0.0         0.0
# 8   9            NaN    Afghanistan 2020-01-30             0.0         0.0
# 9  10            NaN    Afghanistan 2020-01-31             0.0         0.0

# %% [markdown]
# **Checking for missing values in train and test set**

# %%
print('# of missing values in training set:')
print(train.isnull().sum())
print('\n# of missing values in test set:')
print(test.isnull().sum())
# Out:
# # of missing values in training set:
# Id                    0
# Province_State    20700
# Country_Region        0
# Date                  0
# ConfirmedCases        0
# Fatalities            0
# dtype: int64
#
# # of missing values in test set:
# ForecastId           0
# Province_State    7740
# Country_Region       0
# Date                 0
# dtype: int64

# %% [markdown]
# ### Dealing with missing values in 'Province_State'

# %%
train.set_index('Id', inplace=True)
train['Region'] = np.nan
train.loc[train.Province_State.isnull(), 'Region'] = train.loc[train.Province_State.isnull(), 'Country_Region']
train.loc[train.Province_State.notnull(), 'Region'] = train.loc[train.Province_State.notnull(), 'Country_Region']\
                                + ' ' + train.loc[train.Province_State.notnull(),'Province_State'].astype('str')
train = train.loc[:, ['Date', 'Region', 'ConfirmedCases', 'Fatalities']]
train.loc[500:1000,:]
# Out:
#            Date                                  Region  ConfirmedCases  \
# Id
# 500  2020-03-01                                  Angola             0.0
# 501  2020-03-02                                  Angola             0.0
# 502  2020-03-03                                  Angola             0.0
# 503  2020-03-04                                  Angola             0.0
# 504  2020-03-05                                  Angola             0.0
# ...         ...                                     ...             ...
# 996  2020-04-06  Australia Australian Capital Territory            96.0
# 997  2020-04-07  Australia Australian Capital Territory            96.0
# 998  2020-04-08  Australia Australian Capital Territory            99.0
# 999  2020-04-09  Australia Australian Capital Territory           100.0
# 1000 2020-04-10  Australia Australian Capital Territory           103.0
#
#       Fatalities
# Id
# 500          0.0
# 501          0.0
# 502          0.0
# 503          0.0
# 504          0.0
# ...          ...
# 996          2.0
# 997          2.0
# 998          2.0
# 999          2.0
# 1000         2.0
#
# [501 rows x 4 columns]

# %%
test.set_index('ForecastId', inplace=True)
test['Region'] = np.nan
test.loc[test.Province_State.isnull(), 'Region'] = test.loc[test.Province_State.isnull(), 'Country_Region']
test.loc[test.Province_State.notnull(), 'Region'] = test.loc[test.Province_State.notnull(), 'Country_Region']\
                                + ' ' + test.loc[test.Province_State.notnull(),'Province_State'].astype('str')
test = test.loc[:, ['Date', 'Region']]
test.loc[500:1000,:]
# Out:
#                  Date                Region
# ForecastId
# 500        2020-04-28  Australia Queensland
# 501        2020-04-29  Australia Queensland
# 502        2020-04-30  Australia Queensland
# 503        2020-05-01  Australia Queensland
# 504        2020-05-02  Australia Queensland
# ...               ...                   ...
# 996        2020-04-08               Belgium
# 997        2020-04-09               Belgium
# 998        2020-04-10               Belgium
# 999        2020-04-11               Belgium
# 1000       2020-04-12               Belgium
#
# [501 rows x 2 columns]

# %% [markdown]
# **Checking for missing values after imputation**

# %%
print('# of missing values in training set:')
print(train.isnull().sum())
print('\n# of missing values in test set:')
print(test.isnull().sum())
# Out:
# # of missing values in training set:
# Date              0
# Region            0
# ConfirmedCases    0
# Fatalities        0
# dtype: int64
#
# # of missing values in test set:
# Date      0
# Region    0
# dtype: int64

# %% [markdown]
# ### Using MinMaxScaler to scale values in 'ConfirmedCases' and 'Fatalities'

# %%
scaler = MinMaxScaler()
scaler.fit(train.loc[:, ['ConfirmedCases', 'Fatalities']])
train.loc[:, ['ConfirmedCases', 'Fatalities']] = scaler.transform(train.loc[:, ['ConfirmedCases', 'Fatalities']])

# %%
# After Scaling
train.loc[500:1000,:]
# Out:
#            Date                                  Region  ConfirmedCases  \
# Id
# 500  2020-03-01                                  Angola        0.000000
# 501  2020-03-02                                  Angola        0.000000
# 502  2020-03-03                                  Angola        0.000000
# 503  2020-03-04                                  Angola        0.000000
# 504  2020-03-05                                  Angola        0.000000
# ...         ...                                     ...             ...
# 996  2020-04-06  Australia Australian Capital Territory        0.000278
# 997  2020-04-07  Australia Australian Capital Territory        0.000278
# 998  2020-04-08  Australia Australian Capital Territory        0.000286
# 999  2020-04-09  Australia Australian Capital Territory        0.000289
# 1000 2020-04-10  Australia Australian Capital Territory        0.000298
#
#       Fatalities
# Id
# 500     0.000000
# 501     0.000000
# 502     0.000000
# 503     0.000000
# 504     0.000000
# ...          ...
# 996     0.000059
# 997     0.000059
# 998     0.000059
# 999     0.000059
# 1000    0.000059
#
# [501 rows x 4 columns]

# %% [markdown]
# ### Next step:
# Create a base time-series model using RNN

# %%
regions = list(train.Region.unique())

train_df = pd.DataFrame()
for region in regions:
    new_df = train.loc[train.Region == region,:]
    for i in range(1,16):
        cc_col = 'ConfirmedCases_' + str(i)
        f_col = 'Fatalities_' + str(i)
        new_df[cc_col] = new_df.ConfirmedCases.shift(i)
        new_df[f_col] = new_df.Fatalities.shift(i)
        #new_df = new_df.iloc[15:,:]
    train_df = pd.concat([train_df, new_df.iloc[15:,:]])
# Out:
# /Users/syedkashif9786/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/syedkashif9786/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# 16211      0.058386  ...           0.100815       0.033943           0.095607
# 16212      0.061798  ...           0.107737       0.035973           0.100815
# 16213      0.065063  ...           0.114799       0.038914           0.107737
# 16214      0.067475  ...           0.122913       0.040914           0.114799
# 16215      0.071034  ...           0.134284       0.046062           0.122913
#
#        Fatalities_12  ConfirmedCases_13  Fatalities_13  ConfirmedCases_14  \
# Id
# 16196       0.011560           0.030227       0.010530           0.026618
# 16197       0.011912           0.033217       0.011560           0.030227
# 16198       0.013177           0.035632       0.011912           0.033217
# 16199       0.014295           0.038836       0.013177           0.035632
# 16200       0.015324           0.041502       0.014295           0.038836
# 16201       0.016442           0.045464       0.015324           0.041502
# 16202       0.017413           0.050938       0.016442           0.045464
# 16203       0.018972           0.053610       0.017413           0.050938
# 16204       0.020031           0.058066       0.018972           0.053610
# 16205       0.021207           0.061796       0.020031           0.058066
# 16206       0.022943           0.066733       0.021207           0.061796
# 16207       0.024266           0.070934       0.022943           0.066733
# 16208       0.025913           0.076004       0.024266           0.070934
# 16209       0.027619           0.080651       0.025913           0.076004
# 16210       0.029649           0.085165       0.027619           0.080651
# 16211       0.031737           0.090581       0.029649           0.085165
# 16212       0.033943           0.095607       0.031737           0.090581
# 16213       0.035973           0.100815       0.033943           0.095607
# 16214       0.038914           0.107737       0.035973           0.100815
# 16215       0.040914           0.114799       0.038914           0.107737
#
#        Fatalities_14  ConfirmedCases_15  Fatalities_15
# Id
# 16196       0.009736           0.024424       0.008471
# 16197       0.010530           0.026618       0.009736
# 16198       0.011560           0.030227       0.010530
# 16199       0.011912           0.033217       0.011560
# 16200       0.013177           0.035632       0.011912
# 16201       0.014295           0.038836       0.013177
# 16202       0.015324           0.041502       0.014295
# 16203       0.016442           0.045464       0.015324
# 16204       0.017413           0.050938       0.016442
# 16205       0.018972           0.053610       0.017413
# 16206       0.020031           0.058066       0.018972
# 16207       0.021207           0.061796       0.020031
# 16208       0.022943           0.066733       0.021207
# 16209       0.024266           0.070934       0.022943
# 16210       0.025913           0.076004       0.024266
# 16211       0.027619           0.080651       0.025913
# 16212       0.029649           0.085165       0.027619
# 16213       0.031737           0.090581       0.029649
# 16214       0.033943           0.095607       0.031737
# 16215       0.035973           0.100815       0.033943
#
# [20 rows x 34 columns]

# %%
test_df = train_df.loc[(train_df.Date >= min(test.Date)) & (train_df.Date <= max(test.Date)),:]
test_df.head()
# Out:
#          Date       Region  ConfirmedCases  Fatalities  ConfirmedCases_1  \
# Id
# 72 2020-04-02  Afghanistan        0.000789    0.000176          0.000685
# 73 2020-04-03  Afghanistan        0.000813    0.000176          0.000789
# 74 2020-04-04  Afghanistan        0.000865    0.000206          0.000813
# 75 2020-04-05  Afghanistan        0.001009    0.000206          0.000865
# 76 2020-04-06  Afghanistan        0.001061    0.000324          0.001009
#
#     Fatalities_1  ConfirmedCases_2  Fatalities_2  ConfirmedCases_3  \
# Id
# 72      0.000118          0.000503      0.000118          0.000492
# 73      0.000176          0.000685      0.000118          0.000503
# 74      0.000176          0.000789      0.000176          0.000685
# 75      0.000206          0.000813      0.000176          0.000789
# 76      0.000206          0.000865      0.000206          0.000813
#
#     Fatalities_3  ...  ConfirmedCases_11  Fatalities_11  ConfirmedCases_12  \
# Id                ...
# 72      0.000118  ...           0.000116       0.000029           0.000069
# 73      0.000118  ...           0.000116       0.000029           0.000116
# 74      0.000118  ...           0.000214       0.000029           0.000116
# 75      0.000176  ...           0.000243       0.000059           0.000214
# 76      0.000176  ...           0.000272       0.000118           0.000243
#
#     Fatalities_12  ConfirmedCases_13  Fatalities_13  ConfirmedCases_14  \
# Id
# 72       0.000000           0.000069       0.000000           0.000064
# 73       0.000029           0.000069       0.000000           0.000069
# 74       0.000029           0.000116       0.000029           0.000069
# 75       0.000029           0.000116       0.000029           0.000116
# 76       0.000059           0.000214       0.000029           0.000116
#
#     Fatalities_14  ConfirmedCases_15  Fatalities_15
# Id
# 72       0.000000           0.000064       0.000000
# 73       0.000000           0.000064       0.000000
# 74       0.000000           0.000069       0.000000
# 75       0.000029           0.000069       0.000000
# 76       0.000029           0.000116       0.000029
#
# [5 rows x 34 columns]

# %%
test_df.index = test.index
test_df.head()
# Out:
#                  Date       Region  ConfirmedCases  Fatalities  \
# ForecastId
# 1          2020-04-02  Afghanistan        0.000789    0.000176
# 2          2020-04-03  Afghanistan        0.000813    0.000176
# 3          2020-04-04  Afghanistan        0.000865    0.000206
# 4          2020-04-05  Afghanistan        0.001009    0.000206
# 5          2020-04-06  Afghanistan        0.001061    0.000324
#
#             ConfirmedCases_1  Fatalities_1  ConfirmedCases_2  Fatalities_2  \
# ForecastId
# 1                   0.000685      0.000118          0.000503      0.000118
# 2                   0.000789      0.000176          0.000685      0.000118
# 3                   0.000813      0.000176          0.000789      0.000176
# 4                   0.000865      0.000206          0.000813      0.000176
# 5                   0.001009      0.000206          0.000865      0.000206
#
#             ConfirmedCases_3  Fatalities_3  ...  ConfirmedCases_11  \
# ForecastId                                  ...
# 1                   0.000492      0.000118  ...           0.000116
# 2                   0.000503      0.000118  ...           0.000116
# 3                   0.000685      0.000118  ...           0.000214
# 4                   0.000789      0.000176  ...           0.000243
# 5                   0.000813      0.000176  ...           0.000272
#
#             Fatalities_11  ConfirmedCases_12  Fatalities_12  \
# ForecastId
# 1                0.000029           0.000069       0.000000
# 2                0.000029           0.000116       0.000029
# 3                0.000029           0.000116       0.000029
# 4                0.000059           0.000214       0.000029
# 5                0.000118           0.000243       0.000059
#
#             ConfirmedCases_13  Fatalities_13  ConfirmedCases_14  \
# ForecastId
# 1                    0.000069       0.000000           0.000064
# 2                    0.000069       0.000000           0.000069
# 3                    0.000116       0.000029           0.000069
# 4                    0.000116       0.000029           0.000116
# 5                    0.000214       0.000029           0.000116
#
#             Fatalities_14  ConfirmedCases_15  Fatalities_15
# ForecastId
# 1                0.000000           0.000064       0.000000
# 2                0.000000           0.000064       0.000000
# 3                0.000000           0.000069       0.000000
# 4                0.000029           0.000069       0.000000
# 5                0.000029           0.000116       0.000029
#
# [5 rows x 34 columns]

# %%
test.head()
# Out:
#                  Date       Region
# ForecastId
# 1          2020-04-02  Afghanistan
# 2          2020-04-03  Afghanistan
# 3          2020-04-04  Afghanistan
# 4          2020-04-05  Afghanistan
# 5          2020-04-06  Afghanistan
